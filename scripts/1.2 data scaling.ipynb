# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
path = path = r'C:\Users\artoe\Documents\DataAnalytics\Machine Learning with Python\Achievement 1\data'

# %%
df = pd.read_csv(os.path.join(path, 'Dataset-weather-prediction-dataset-processed.csv'), index_col=False)

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
df.tail()
# Out:
#            DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 22945  20221027     10                  1               2.1            0.79
# 22946  20221028     10                  6               2.1            0.77
# 22947  20221029     10                  4               2.1            0.76
# 22948  20221030     10                  5               2.1            0.80
# 22949  20221031     10                  5               2.1            0.84
#
#        BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 22945          1.0248                    1.34                 0.22
# 22946          1.0244                    1.34                 0.22
# 22947          1.0227                    1.34                 0.22
# 22948          1.0212                    1.34                 0.22
# 22949          1.0193                    1.34                 0.22
#
#        BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# ...

# %%
df.shape
# Out:
# (22950, 170)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 170 entries, DATE to VALENTIA_temp_max
# dtypes: float64(145), int64(25)
# memory usage: 29.8 MB

# %%
#check for nulls
df.isnull().sum()
# Out:
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
# BASEL_humidity         0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 170, dtype: int64

# %%
#no nulls

# %%
#apply standard scaler function
scaler = StandardScaler()

# %%
#DATE and MONTH columns should probably not be scaled
cols_to_scale = [col for col in df.columns if col not in ['DATE', 'MONTH']]

# %%
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
#check scaled df
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1           0.660514          -0.02793        0.826097
# 1  19600102      1           0.244897          -0.02793        0.735760
# 2  19600103      1           1.076130          -0.02793        1.277781
# 3  19600104      1          -1.001953          -0.02793        1.458455
# 4  19600105      1           0.244897          -0.02793        1.729466
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0       -0.001949               -1.101066            -0.265148
# 1       -0.001949               -1.058108             1.658760
# 2       -0.001949               -1.251420             0.155707
# 3       -0.001949               -0.821838            -0.445514
# 4       -0.001949               -0.746661            -0.164944
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0         -0.179228       -0.902918  ...             -0.443701
# ...

# %%
df.tail()
# Out:
#            DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 22945  20221027     10          -1.833187          -0.02793        0.284075
# 22946  20221028     10           0.244897          -0.02793        0.103401
# 22947  20221029     10          -0.586336          -0.02793        0.013064
# 22948  20221030     10          -0.170720          -0.02793        0.374412
# 22949  20221031     10          -0.170720          -0.02793        0.735760
#
#        BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 22945        1.037367               -0.005632            -0.004619
# 22946        0.976231               -0.005632            -0.004619
# 22947        0.716402               -0.005632            -0.004619
# 22948        0.487141               -0.005632            -0.004619
# 22949        0.196744               -0.005632            -0.004619
#
#        BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# ...

# %%
df.shape
# Out:
# (22950, 170)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 170 entries, DATE to VALENTIA_temp_max
# dtypes: float64(168), int64(2)
# memory usage: 29.8 MB

# %%
#export scaled data
df.to_csv(os.path.join(path, 'weather_scaled.csv'))
